# %% [markdown]
# # Creating Listing DataFrame using zip() function.

# %%
# Python program to demonstrate creating
# pandas Datadaframe from lists using zip.
   
import pandas as pd

# List1
seller_id = ["0UHcspYV2NOUc5yZTFkslMuYRD23", "HR6QlZUlyacmra6d3inTTrbw8sf2", "HxjkE2HdQMWmOYbVQCbPYtI817x2", "fkeyaGS8FFTwtqoxkW2XBd4yI182", "0UHcspYV2NOUc5yZTFkslMuYRD23", "HR6QlZUlyacmra6d3inTTrbw8sf2", "HxjkE2HdQMWmOYbVQCbPYtI817x2", "HR6QlZUlyacmra6d3inTTrbw8sf2", "0UHcspYV2NOUc5yZTFkslMuYRD23", "0UHcspYV2NOUc5yZTFkslMuYRD23", "HxjkE2HdQMWmOYbVQCbPYtI817x2", "HxjkE2HdQMWmOYbVQCbPYtI817x2", "HxjkE2HdQMWmOYbVQCbPYtI817x2", "0UHcspYV2NOUc5yZTFkslMuYRD23", "fkeyaGS8FFTwtqoxkW2XBd4yI182"]
   
# List1
product_name = ['SEVENTEEN Attacca Album photocard', 
                'SEVENTEEN Heng Garæ Album photocard', 
                'SEVENTEEN Haru Tour trading card', 
                'SEVENTEEN Incomplete 2021 trading cards', 
                'SEVENTEEN Heng Garæ Album photocard', 
                'SEVENTEEN Incomplete 2021 trading card', 
                'SEVENTEEN Haru Tour trading card', 
                'SEVENTEEN Incomplete 2021 trading card', 
                'SEVENTEEN Attacca Album photocards', 
                'SEVENTEEN Haru Tour trading card', 
                'SEVENTEEN Attacca Album photocard', 
                'SEVENTEEN Haru Tour trading card', 
                'SEVENTEEN Attacca Album photocard', 
                'SEVENTEEN Caratland 2021 trading card', 
                'SEVENTEEN Caratland 2021 trading card']
   
# List2
product_status = ['Ships from Korea + Release Date : 2021.10.22 + CD and 78p Photobook + Lyric Case + Photo Postcard (Random 1 out of 13) + Folding Card (Random 1 out of 13) + Photocard (Random 2 out of 26) + Layered Card (FIRST PRESS ONLY) + Folded Poster (Random 1 out of 4) + Double-Side Extra Photocards Set + 100% Original Brand New Item.'
 , 'Release Date : 2020.06.23 + Made from Korea + Officially distributed Brand New & Factory Sealed CD + 4ea Photobooks + 1 Sticker + 1 Lyric Paper + Photocards(Random 2 out of 26) + Bookmark(Random 1 out of 13) + FOLDED POSTER(RANDOM 1 OUT OF 4)'
 , 'New + all authentic + personally brought home from japan!'
 , 'It can have small spots or scratches from its production process. Therefore, we always double check all the photo cards very carefully so most of our goods do not have any notable defects.'
 , 'Used + Good condition + No defects + + FREE GIFT 1 SEVENTEEN Logo Printed Hand Mirror and Extra Photocards (Only ""MOMS HOBBY"" Store Gift)'
, 'Brand new + There may be delays with shipping.'
, 'This is a used SEVENTEEN 2019 Japan Tour Haru Sebuchi Harukon with Trekka Blu-ray'
, 'It can have small spots or scratches from its production process. Therefore, we always double check all the photo cards very carefully so most of our goods do not have any notable defects.'
, 'Buy SET, and get 3 undisclosed photocards + a set of 3 PVC card cases + 1 undisclosed group photo transparent mini poster'
, 'Good condition + SEVENTEEN OFFICIAL HARU TOUR IN JAPAN TRADING CARD UNSEALED & LOOSE'
, 'Buy RANDOM, and get 1 photocard case + 1 PVC card case'
, 'Mint Condition + Official 2019 Japan Tour HARU trading cards + Selling as member sets (8 cards per member)'
, 'slight scratches and discolorations'
, 'Brand new 28 special cards + hand written message from members to CARAT'
, '70 good condition regular cards']

# List5
product_image = ['https://cf.shopee.com.my/file/6e5fe62650a0c7d50a53e78c66cf0c92', 
                 'https://d1w8cc2yygc27j.cloudfront.net/2980183017174293227/1161292534454469943.jpg',
                 'https://media.karousell.com/media/photos/products/2019/07/10/wts_seventeen_haru_2019_japan_tour_trading_card_1562735469_048d60ea_progressive.jpg', 
                 'https://media.karousell.com/media/photos/products/2022/3/13/seventeen_incomplete_trading_c_1647157590_066299fd_progressive.jpg', 
                 'https://d1w8cc2yygc27j.cloudfront.net/2980183017174293227/1161292534454469943.jpg', 
                 'https://media.karousell.com/media/photos/products/2022/3/13/seventeen_incomplete_trading_c_1647157590_066299fd_progressive.jpg', 
                 'https://media.karousell.com/media/photos/products/2019/07/10/wts_seventeen_haru_2019_japan_tour_trading_card_1562735469_048d60ea_progressive.jpg', 
                 'https://media.karousell.com/media/photos/products/2022/3/13/seventeen_incomplete_trading_c_1647157590_066299fd_progressive.jpg', 
                 'https://cdn.shopify.com/s/files/1/0558/0429/7407/products/1_0d7950cb-1bcf-4e60-8103-f07374e5bca7_1296x.jpg?v=1636359703', 
                 'https://cdn.shopify.com/s/files/1/0514/7069/6632/products/pr-weverse-shop-pre-order-seventeen-in-carat-land-2021-5th-fan-meeting-official-md-2nd-line-28568158961744_967x_bf37a13a-1dd4-46d5-a0fe-bbba00d2dc9d_1512x.jpg?v=1628048816', 
                 'https://cdn.shopify.com/s/files/1/0558/0429/7407/products/1_0d7950cb-1bcf-4e60-8103-f07374e5bca7_1296x.jpg?v=1636359703', 
                 'https://64.media.tumblr.com/91d45b0cd5833aee7ed0aaa23eecb005/tumblr_ppbbnty4GH1rz50d9o1_1280.jpg', 
                 'https://cf.shopee.com.my/file/6e5fe62650a0c7d50a53e78c66cf0c92', 
                 'https://www.kpoptown.com/115884-large_default/seventeen-2021-carat-land-goods-trading-card-binder.jpg', 
                 'https://www.kpoptown.com/115884-large_default/seventeen-2021-carat-land-goods-trading-card-binder.jpg']

# List3
category = ['Album photocard', 'Album photocard', 'trading card', 'trading card', 'Album photocard', 'trading card', 'trading card', 'trading card', 'Album photocard', 'trading card', 'Album photocard', 'trading card', 'Album photocard', 'trading card', 'trading card']

# List3
product_pricing = ['buy now', 'buy now', 'buy now', 'buy now', 'buy now', 'buy now', 'buy now', 'buy now', 'buy now', 'bid now', 'buy now', 'buy now', 'bid now', 'bid now', 'buy now']

# List4
price = [278000, 500000, 300000, 200000, 70000, 90000, 20000, 180000, 200000, 299000, 400000, 100000, 100000, 500000, 700000]


# get the list of tuples from two lists.
# and merge them by using zip().
list_of_tuples = list(zip(seller_id, product_name, product_status, product_image, category, product_pricing, price))
   
# Assign data to tuples.
list_of_tuples 
 
# Converting lists of tuples into
# pandas Dataframe.
df = pd.DataFrame(list_of_tuples,
                  columns = ['seller_id', 'product_name', 'product_status', 'product_image', 'category', 'product_pricing', 'price'])

# added static columns inside the dataframe 
df['availability'] = 'available'

# Cast all values inside the dataframe (except the columns' name) into lowercase
df = df.applymap(lambda s: s.lower() if type(s) == str else s)


# added current date time
# df['date_time'] = pd.to_datetime('now', utc=True)
df['date_time'] = "Fri Apr 22 2022 14:23:42 GMT+0700 (Indochina Time)"
df.to_csv('data/interim/listing.csv', index=False)

# Print data.
df.head()
# Out:
#                       seller_id                             product_name  \
# 0  0uhcspyv2nouc5yztfkslmuyrd23        seventeen attacca album photocard
# 1  hr6qlzulyacmra6d3inttrbw8sf2      seventeen heng garæ album photocard
# 2  hxjke2hdqmwmoybvqcbpyti817x2         seventeen haru tour trading card
# 3  fkeyags8fftwtqoxkw2xbd4yi182  seventeen incomplete 2021 trading cards
# 4  0uhcspyv2nouc5yztfkslmuyrd23      seventeen heng garæ album photocard
#
#                                       product_status  \
# 0  ships from korea + release date : 2021.10.22 +...
# 1  release date : 2020.06.23 + made from korea + ...
# 2  new + all authentic + personally brought home ...
# 3  it can have small spots or scratches from its ...
# 4  used + good condition + no defects + + free gi...
#
#                                        product_image         category  \
# 0  https://cf.shopee.com.my/file/6e5fe62650a0c7d5...  album photocard
# ...

# %%
df.product_status.unique()
# Out:
# array(['ships from korea + release date : 2021.10.22 + cd and 78p photobook + lyric case + photo postcard (random 1 out of 13) + folding card (random 1 out of 13) + photocard (random 2 out of 26) + layered card (first press only) + folded poster (random 1 out of 4) + double-side extra photocards set + 100% original brand new item.',
#        'release date : 2020.06.23 + made from korea + officially distributed brand new & factory sealed cd + 4ea photobooks + 1 sticker + 1 lyric paper + photocards(random 2 out of 26) + bookmark(random 1 out of 13) + folded poster(random 1 out of 4)',
#        'new + all authentic + personally brought home from japan!',
#        'it can have small spots or scratches from its production process. therefore, we always double check all the photo cards very carefully so most of our goods do not have any notable defects.',
# ...

# %%
df.to_json('data/interim/listing.json', orient='records')
